# %% [markdown]
# <a href="https://colab.research.google.com/github/ccosmin97/IDC-Examples-fix-bg/blob/master/notebooks/cookbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IDC Google Colab cookbook notebook
#
# The goal of this notebook is to serve as the source of various small bits that should be helpful in developing analysis notebooks by the IDC users.
#
# Please email Andrey Fedorov andrey dot fedorov at gmail dot com if you have any questions or suggestions!
#
# Prepared: Spring 2022
#
# Updated: July 2022

# %% [markdown]
# # Prerequisites
#
# Please complete the prerequisites as described in this documentation page: https://learn.canceridc.dev/introduction/getting-started-with-gcp.
#
# Insert that project ID in the cell below in place of `REPLACE_ME_WITH_YOUR_PROJECT_ID`.

# %%
# initialize this variable with your Google Cloud Project ID!
my_ProjectID = "idc-sandbox-003"#"REPLACE_ME_WITH_YOUR_PROJECT_ID"

import os
os.environ["GCP_PROJECT_ID"] = my_ProjectID

# %% [markdown]
# # Authentication

# %%
# you will need to authenticate with your Google ID to do anything meaningful with IDC
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # Query
#
# First, instantiate the query client, which can next be configured to run the query.

# %%
# python API is the most flexible way to query IDC BigQuery metadata tables
from google.cloud import bigquery
bq_client = bigquery.Client(my_ProjectID)

# %% [markdown]
# ## Select by specific UID
#
# Queries below are against the [`dicom_all` table](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=idc_current&t=dicom_all&page=table) that has one row per DICOM file stored in IDC. That table contains the metadata extracted from DICOM files, collection-level attributes (e.g., ID of the collection, license, DOI of the collection), and URLs pointing to the location in the cloud where the file is stored.

# %%
# select rows corresponding to the specific DICOM instance, as defined by SOPInstanceUID value
# similarly, you can select by specifying StudyInstanceUID, SeriesInstanceUID or SOPInstanceUID,
# replacing the PatientID line below with the following (as examples): 
#   SOPInstanceUID = \"1.3.6.1.4.1.14519.5.2.1.6450.2626.226637977389233552278537838820\" 
#   SeriesInstanceUID = \"1.3.6.1.4.1.14519.5.2.1.4334.1501.312037286778380630549945195741\" 
#   StudyInstanceUID = \"	1.3.6.1.4.1.14519.5.2.1.4334.1501.116796918629271881210561198785\" 
selection_query = """
  SELECT  
    StudyInstanceUID, 
    SeriesInstanceUID, 
    SOPInstanceUID, 
    instance_size, 
    gcs_url 
  FROM 
    `bigquery-public-data.idc_current.dicom_all` 
  WHERE 
    PatientID = "R01-001"
"""

selection_result = bq_client.query(selection_query)
selection_df = selection_result.result().to_dataframe()

# %%
size_gb = selection_df["instance_size"].sum()/(1024*1024*1024)
print(f"Cohort size on disk: {size_gb} Gb")
# Out:
# Cohort size on disk: 0.273021187633276 Gb

# %% [markdown]
# ## Select by availability of segmentations

# %% [markdown]
# What segmentations do we have anyway? Let's look at the distinct combinations of segmentation property category, type and anatomic location, which are the metadata attributes that describe segmentations.

# %%
# %%bigquery --project=$my_ProjectID
#
# SELECT
#   DISTINCT(SegmentedPropertyCategory.CodeMeaning) as SegmentedPropertyCategory_CodeMeaning,
#   SegmentedPropertyType.CodeMeaning as SegmentedPropertyType_CodeMeaning,
#   AnatomicRegion.CodeMeaning as AnatomicRegion_CodeMeaning
# FROM
#   `bigquery-public-data.idc_current.segmentations`
# Out:
#    SegmentedPropertyCategory_CodeMeaning  \
# 0       Morphological Abnormal Structure
# 1                                 Tissue
# 2                                 Tissue
# 3      Morphologically Altered Structure
# 4      Morphologically Altered Structure
# 5      Morphologically Altered Structure
# 6      Morphologically Altered Structure
# 7      Morphologically Altered Structure
# 8                   Anatomical Structure
# 9                   Anatomical Structure
# 10                  Anatomical Structure
# 11                  Anatomical Structure
# 12     Morphologically Altered Structure
# 13     Morphologically Altered Structure
# 14    Morphologically abnormal structure
# 15                                Tissue
# 16     Morphologically Altered Structure
# 17        Spatial and Relational Concept
# 18                  Anatomical Structure
# 19     Morphologically Altered Structure
# 20                  Anatomical Structure
# 21                                Tissue
# 22                  Anatomical Structure
# 23     Morphologically Altered Structure
# 24                                Tissue
# 25                  Anatomical Structure
# 26     Morphologically Altered Structure
# 27                  Anatomical Structure
# 28                                Tissue
# 29     Morphologically Altered Structure
# 30                  Anatomical Structure
# 31     Morphologically Altered Structure
# 32        Spatial and Relational Concept
# 33                       Physical Object
# 34                  Anatomical Structure
# 35     Morphologically Altered Structure
# 36     Morphologically Altered Structure
# 37        Spatial and Relational Concept
# 38                                Tissue
# 39                  Anatomical Structure
#
#             SegmentedPropertyType_CodeMeaning       AnatomicRegion_CodeMeaning
# 0                                      Nodule                             Lung
# 1               Mammary Fibroglandular Tissue                           Breast
# 2                                      Breast                           Breast
# 3                                    Neoplasm                      Entire body
# 4                                        Mass                             None
# 5                         Neoplasm, Secondary      lymph node of head and neck
# 6                            Enhancing Lesion                            Brain
# 7                           Neoplasm, Primary                    Head and Neck
# 8                                   Esophagus                             None
# 9                                        Lung                             None
# 10  Anterior fibromuscular stroma of prostate                             None
# 11                                Spinal cord                             None
# 12                                      Edema                            Brain
# 13                                   Necrosis                            Brain
# 14                                   Neoplasm                             None
# 15                                  DWI Tumor                           Breast
# 16                          Neoplasm, Primary      pharyngeal tonsil (adenoid)
# 17                           Reference Region                      Aortic arch
# 18                          Prostatic Urethra                             None
# 19                          Neoplasm, Primary                   base of tongue
# 20                                     Kidney                             None
# 21                     Fatty tissue of breast                           Breast
# 22                                   Prostate                             None
# 23                          Neoplasm, Primary                             Lung
# 24                                     Tissue                           Tissue
# 25                Peripheral zone of prostate                             None
# 26                          Neoplasm, Primary                      nasopharynx
# 27                Transition zone of prostate                             None
# 28                                     Normal  Peripheral zone of the prostate
# 29                          Neoplasm, Primary                   pyriform sinus
# 30                                      Heart                             None
# 31                          Neoplasm, Primary                      hypopharynx
# 32                           Reference Region                            Liver
# 33                                      Heart                  Physical Object
# 34            Peripheral zone of the prostate                             None
# 35                                     Lesion  Peripheral zone of the prostate
# 36                          Neoplasm, Primary                       oropharynx
# 37                           Reference Region                       Cerebellum
# 38                                     Tissue                             None
# 39                                  upper arm                             None

# %% [markdown]
# Select all rows that correspond to the instances of segmentations of anything in the prostate.

# %%
# select rows corresponding to cases that have segmentation of prostate tumor
selection_query = f"""
  SELECT  
    dicom_all.StudyInstanceUID, 
    dicom_all.SeriesInstanceUID, 
    dicom_all.SOPInstanceUID, 
    gcs_url 
  FROM 
    `bigquery-public-data.idc_current.dicom_all` as dicom_all 
  JOIN 
    `bigquery-public-data.idc_current.segmentations` as segmentations 
  ON 
    dicom_all.SOPInstanceUID = segmentations.SOPInstanceUID 
  WHERE 
    segmentations.SegmentedPropertyType.CodeMeaning LIKE "%prostate%" OR 
    segmentations.AnatomicRegion.CodeMeaning LIKE "%prostate%"
    """

selection_result = bq_client.query(selection_query)
selection_df = selection_result.result().to_dataframe()

# %%
selection_df
# Out:
#                                       StudyInstanceUID  \
# 0    1.3.6.1.4.1.14519.5.2.1.3671.4754.288848219213...
# 1    1.3.6.1.4.1.14519.5.2.1.3671.4754.288848219213...
# 2    1.3.6.1.4.1.14519.5.2.1.3671.4754.288848219213...
# 3    1.3.6.1.4.1.14519.5.2.1.3671.4754.131608903441...
# 4    1.3.6.1.4.1.14519.5.2.1.3671.4754.131608903441...
# ..                                                 ...
# 525  1.3.6.1.4.1.14519.5.2.1.7310.5101.808270842417...
# 526  1.3.6.1.4.1.14519.5.2.1.7310.5101.808270842417...
# 527  1.3.6.1.4.1.14519.5.2.1.7310.5101.808270842417...
# 528  1.3.6.1.4.1.14519.5.2.1.3671.4754.133806669697...
# 529  1.3.6.1.4.1.14519.5.2.1.3671.4754.133806669697...
#
#                                      SeriesInstanceUID  \
# 0    1.2.276.0.7230010.3.1.3.1426846371.5420.151320...
# 1    1.2.276.0.7230010.3.1.3.1426846371.5420.151320...
# 2    1.2.276.0.7230010.3.1.3.1426846371.5420.151320...
# 3    1.2.276.0.7230010.3.1.3.1426846371.17976.15132...
# 4    1.2.276.0.7230010.3.1.3.1426846371.17976.15132...
# ..                                                 ...
# 525  1.2.276.0.7230010.3.1.3.1070885483.13380.15991...
# 526  1.2.276.0.7230010.3.1.3.1070885483.13380.15991...
# 527  1.2.276.0.7230010.3.1.3.1070885483.13380.15991...
# 528  1.2.276.0.7230010.3.1.3.1426846371.12016.15132...
# 529  1.2.276.0.7230010.3.1.3.1426846371.12016.15132...
#
#                                         SOPInstanceUID  \
# 0    1.2.276.0.7230010.3.1.4.1426846371.5420.151320...
# 1    1.2.276.0.7230010.3.1.4.1426846371.5420.151320...
# 2    1.2.276.0.7230010.3.1.4.1426846371.5420.151320...
# 3    1.2.276.0.7230010.3.1.4.1426846371.17976.15132...
# 4    1.2.276.0.7230010.3.1.4.1426846371.17976.15132...
# ..                                                 ...
# 525  1.2.276.0.7230010.3.1.4.1070885483.13380.15991...
# 526  1.2.276.0.7230010.3.1.4.1070885483.13380.15991...
# 527  1.2.276.0.7230010.3.1.4.1070885483.13380.15991...
# 528  1.2.276.0.7230010.3.1.4.1426846371.12016.15132...
# 529  1.2.276.0.7230010.3.1.4.1426846371.12016.15132...
#
#                                                gcs_url
# 0    gs://public-datasets-idc/f1907408-9c91-43c4-bd...
# 1    gs://public-datasets-idc/f1907408-9c91-43c4-bd...
# 2    gs://public-datasets-idc/f1907408-9c91-43c4-bd...
# 3    gs://public-datasets-idc/26d7e17c-7bc5-4c51-8b...
# 4    gs://public-datasets-idc/26d7e17c-7bc5-4c51-8b...
# ..                                                 ...
# 525  gs://public-datasets-idc/80f2eec5-e6b2-41b7-9b...
# 526  gs://public-datasets-idc/80f2eec5-e6b2-41b7-9b...
# 527  gs://public-datasets-idc/80f2eec5-e6b2-41b7-9b...
# 528  gs://public-datasets-idc/c2ddd0fb-caea-4bea-ba...
# 529  gs://public-datasets-idc/c2ddd0fb-caea-4bea-ba...
#
# [530 rows x 4 columns]

# %% [markdown]
# # Visualization

# %%
# helper function to view a study or a specific series hosted by IDC
def get_idc_viewer_url(studyUID, seriesUID=None):
  url = "https://viewer.imaging.datacommons.cancer.gov/viewer/"+studyUID
  if seriesUID is not None:
    url = url+"?seriesInstanceUID="+seriesUID
  return url

my_StudyInstanceUID = selection_df["StudyInstanceUID"][0]
my_SeriesInstanceUID = selection_df[selection_df["StudyInstanceUID"] == selection_df["StudyInstanceUID"][0]]["SeriesInstanceUID"][0]

print("URL to view the entire study:")
print(get_idc_viewer_url(my_StudyInstanceUID))
# Out:
# URL to view the entire study:
# https://viewer.imaging.datacommons.cancer.gov/viewer/1.3.6.1.4.1.14519.5.2.1.3671.4754.288848219213026850354055725664

# %% [markdown]
# # Downloading
#
# Downloading is easiest using the `gsutil` command line tool that is preinstalled in Colab. `gsutil`, however, is not the fastest tool for downloading data, which is particulary important for large datasets. In the following we discuss two tools that you can use. Complete documentation relarted to downloading data is here: https://learn.canceridc.dev/data/downloading-data.

# %% [markdown]
# ## `gsutil`

# %%
import os
os.environ["DOWNLOAD_DEST"] = "/content/IDC_downloads"
os.environ["MANIFEST"] = "/content/idc_manifest.txt"

# %%
# !mkdir -p ${DOWNLOAD_DEST}
# !echo "gsutil cp \$* $DOWNLOAD_DEST" > gsutil_download.sh
# !chmod +x gsutil_download.sh

# %%
# creating a manifest file for the subsequent download of files
selection_df["gcs_url"].to_csv(os.environ["MANIFEST"], header=False, index=False)

# %%
# download is this simple
# %%capture

# !cat ${MANIFEST} | gsutil -m cp -I ${DOWNLOAD_DEST}

# %% [markdown]
# If you want to download a non-trivial amount of data, you will want to parallelize downloads, as illustrated below.

# %%
# !cat ${MANIFEST} | xargs -n 25 -P 10 ./gsutil_download.sh
# Out:
# Copying gs://public-datasets-idc/7a73c7ce-b30c-4984-ab22-3fcaff395781.dcm...
# Copying gs://public-datasets-idc/7a73c7ce-b30c-4984-ab22-3fcaff395781.dcm...
# Copying gs://public-datasets-idc/9e6d816f-73bb-4e46-8c07-00dec8c831c1.dcm...
# Copying gs://public-datasets-idc/b630454f-147c-4e8a-8394-cc2c08f976bd.dcm...
# Copying gs://public-datasets-idc/a9becaad-6cd1-4ec1-be7b-3c8b3700e07c.dcm...
# Copying gs://public-datasets-idc/7d149412-2d47-4560-a408-ea639e08c833.dcm...
# Copying gs://public-datasets-idc/b630454f-147c-4e8a-8394-cc2c08f976bd.dcm...
# Copying gs://public-datasets-idc/a9becaad-6cd1-4ec1-be7b-3c8b3700e07c.dcm...
# / [3 files][  1.3 MiB/  1.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/b630454f-147c-4e8a-8394-cc2c08f976bd.dcm...
# Copying gs://public-datasets-idc/97167933-28a4-4486-9392-32e81a452c41.dcm...
# Copying gs://public-datasets-idc/b09b397a-e153-4e88-8b44-7d7866bf59db.dcm...
# - [5 files][ 10.3 MiB/ 11.4 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/97167933-28a4-4486-9392-32e81a452c41.dcm...
# Copying gs://public-datasets-idc/459e0f82-8d42-4202-8b7c-e1720b5ff30a.dcm...
# Copying gs://public-datasets-idc/97167933-28a4-4486-9392-32e81a452c41.dcm...
# Copying gs://public-datasets-idc/b09b397a-e153-4e88-8b44-7d7866bf59db.dcm...
# Copying gs://public-datasets-idc/226f63d7-2e49-4db0-9cc0-62617e52d591.dcm...
# Copying gs://public-datasets-idc/b09b397a-e153-4e88-8b44-7d7866bf59db.dcm...
# Copying gs://public-datasets-idc/9f06c077-c6ea-4b34-abc1-a0601691b8c6.dcm...
# Copying gs://public-datasets-idc/226f63d7-2e49-4db0-9cc0-62617e52d591.dcm...
# Copying gs://public-datasets-idc/bcdfc634-f8a4-41aa-aa56-598fc163487d.dcm...
# Copying gs://public-datasets-idc/226f63d7-2e49-4db0-9cc0-62617e52d591.dcm...
# Copying gs://public-datasets-idc/9f06c077-c6ea-4b34-abc1-a0601691b8c6.dcm...
# Copying gs://public-datasets-idc/8184b96e-1823-4dd2-b0a6-3c152bf2c1e8.dcm...
# \ [9 files][ 15.3 MiB/ 15.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/967d17d9-37a5-43d9-831e-19742b62beef.dcm...
# Copying gs://public-datasets-idc/8184b96e-1823-4dd2-b0a6-3c152bf2c1e8.dcm...
# Copying gs://public-datasets-idc/9f06c077-c6ea-4b34-abc1-a0601691b8c6.dcm...
# Copying gs://public-datasets-idc/6f54022f-78e3-4b0a-b308-b8c81b499995.dcm...
# Copying gs://public-datasets-idc/bcdfc634-f8a4-41aa-aa56-598fc163487d.dcm...
# Copying gs://public-datasets-idc/8184b96e-1823-4dd2-b0a6-3c152bf2c1e8.dcm...
# Copying gs://public-datasets-idc/967d17d9-37a5-43d9-831e-19742b62beef.dcm...
# Copying gs://public-datasets-idc/429f3b45-853d-4720-b23a-e0e38f14d0f4.dcm...
# Copying gs://public-datasets-idc/6f54022f-78e3-4b0a-b308-b8c81b499995.dcm...
# Copying gs://public-datasets-idc/8a4a5d27-bbb2-4a9b-a536-731633836b97.dcm...
# Copying gs://public-datasets-idc/bcdfc634-f8a4-41aa-aa56-598fc163487d.dcm...
# Copying gs://public-datasets-idc/967d17d9-37a5-43d9-831e-19742b62beef.dcm...
# Copying gs://public-datasets-idc/6f54022f-78e3-4b0a-b308-b8c81b499995.dcm...
# Copying gs://public-datasets-idc/429f3b45-853d-4720-b23a-e0e38f14d0f4.dcm...
# Copying gs://public-datasets-idc/8a4a5d27-bbb2-4a9b-a536-731633836b97.dcm...
# Copying gs://public-datasets-idc/66bbd119-a2de-4c39-9b1c-f52589d5be5d.dcm...
# Copying gs://public-datasets-idc/429f3b45-853d-4720-b23a-e0e38f14d0f4.dcm...
# Copying gs://public-datasets-idc/32c15ca0-d5a1-40c6-b680-e27b469a6a99.dcm...
# Copying gs://public-datasets-idc/39a66342-0ab5-47f4-ab8a-c20da2102d02.dcm...
# Copying gs://public-datasets-idc/805687a6-fe73-4e9b-b4f9-5cd3c33fbae7.dcm...
# Copying gs://public-datasets-idc/9e926367-3c87-43b8-9808-363635606e41.dcm...
# Copying gs://public-datasets-idc/f1907408-9c91-43c4-bdc1-624743832d89.dcm...
# Copying gs://public-datasets-idc/efb9e0fa-2c61-4682-a0df-968545d64b0b.dcm...
# Copying gs://public-datasets-idc/66bbd119-a2de-4c39-9b1c-f52589d5be5d.dcm...
# Copying gs://public-datasets-idc/805687a6-fe73-4e9b-b4f9-5cd3c33fbae7.dcm...
# Copying gs://public-datasets-idc/e938efc5-548b-465e-ae73-aa42fec4cd98.dcm...
# Copying gs://public-datasets-idc/32c15ca0-d5a1-40c6-b680-e27b469a6a99.dcm...
# Copying gs://public-datasets-idc/f1907408-9c91-43c4-bdc1-624743832d89.dcm...
# Copying gs://public-datasets-idc/9e926367-3c87-43b8-9808-363635606e41.dcm...
# Copying gs://public-datasets-idc/39a66342-0ab5-47f4-ab8a-c20da2102d02.dcm...
# Copying gs://public-datasets-idc/3687541b-37f7-4a4c-bcb4-174bab7ea8f9.dcm...
# Copying gs://public-datasets-idc/d5816719-b264-4695-8d7d-2a0d65d50c8e.dcm...
# Copying gs://public-datasets-idc/f1907408-9c91-43c4-bdc1-624743832d89.dcm...
# Copying gs://public-datasets-idc/48f9b95a-8fd1-4354-9465-0f040a4c3317.dcm...
# |
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/efb9e0fa-2c61-4682-a0df-968545d64b0b.dcm...
# Copying gs://public-datasets-idc/8b189a72-bf4b-4508-8744-d74c39de0bb8.dcm...
# / [2 files][  3.1 MiB/  3.1 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/805687a6-fe73-4e9b-b4f9-5cd3c33fbae7.dcm...
# Copying gs://public-datasets-idc/e938efc5-548b-465e-ae73-aa42fec4cd98.dcm...
# Copying gs://public-datasets-idc/d8decced-2830-43b2-9a4f-26d8bfe84de0.dcm...
# Copying gs://public-datasets-idc/7d149412-2d47-4560-a408-ea639e08c833.dcm...
# Copying gs://public-datasets-idc/26d7e17c-7bc5-4c51-8b48-82b54e814495.dcm...
# Copying gs://public-datasets-idc/48f9b95a-8fd1-4354-9465-0f040a4c3317.dcm...
# Copying gs://public-datasets-idc/d5816719-b264-4695-8d7d-2a0d65d50c8e.dcm...
# Copying gs://public-datasets-idc/3687541b-37f7-4a4c-bcb4-174bab7ea8f9.dcm...
# Copying gs://public-datasets-idc/e938efc5-548b-465e-ae73-aa42fec4cd98.dcm...
# Copying gs://public-datasets-idc/d39e9e66-4d37-4a25-87aa-9b84e5d345b9.dcm...
# Copying gs://public-datasets-idc/8b189a72-bf4b-4508-8744-d74c39de0bb8.dcm...
# Copying gs://public-datasets-idc/7d149412-2d47-4560-a408-ea639e08c833.dcm...
# \ [5 files][ 12.3 MiB/ 12.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/26d7e17c-7bc5-4c51-8b48-82b54e814495.dcm...
# - [4 files][  2.8 MiB/  3.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/d5816719-b264-4695-8d7d-2a0d65d50c8e.dcm...
# Copying gs://public-datasets-idc/efb9e0fa-2c61-4682-a0df-968545d64b0b.dcm...
# Copying gs://public-datasets-idc/48f9b95a-8fd1-4354-9465-0f040a4c3317.dcm...
# Copying gs://public-datasets-idc/d8decced-2830-43b2-9a4f-26d8bfe84de0.dcm...
# \ [3 files][  4.6 MiB/  4.6 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/8b189a72-bf4b-4508-8744-d74c39de0bb8.dcm...
# Copying gs://public-datasets-idc/5f7a0faf-06dc-4852-8226-fe408d9d8bad.dcm...
# Copying gs://public-datasets-idc/d39e9e66-4d37-4a25-87aa-9b84e5d345b9.dcm...
# Copying gs://public-datasets-idc/039a2691-c467-422e-b6d6-3558da024a81.dcm...
# Copying gs://public-datasets-idc/3687541b-37f7-4a4c-bcb4-174bab7ea8f9.dcm...
# Copying gs://public-datasets-idc/96bbc607-5500-4130-831f-c248ae143f55.dcm...
# Copying gs://public-datasets-idc/26d7e17c-7bc5-4c51-8b48-82b54e814495.dcm...
# Copying gs://public-datasets-idc/cf4a68d1-e5d5-445c-8d06-9b20d890538c.dcm...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/d8decced-2830-43b2-9a4f-26d8bfe84de0.dcm...
# Copying gs://public-datasets-idc/96bbc607-5500-4130-831f-c248ae143f55.dcm...
# Copying gs://public-datasets-idc/aca9012f-f897-483f-91fa-6c7c4608dbdf.dcm...
# Copying gs://public-datasets-idc/b0f35b02-b4a8-401e-913b-1343401942b2.dcm...
# Copying gs://public-datasets-idc/ac2f3019-f75b-4a89-b001-3ca17355e59c.dcm...
# \ [5 files][  5.8 MiB/  7.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/039a2691-c467-422e-b6d6-3558da024a81.dcm...
# Copying gs://public-datasets-idc/d39e9e66-4d37-4a25-87aa-9b84e5d345b9.dcm...
# Copying gs://public-datasets-idc/5f7a0faf-06dc-4852-8226-fe408d9d8bad.dcm...
# Copying gs://public-datasets-idc/56866f5f-1d17-48ed-8ed3-5218adc662b5.dcm...
# Copying gs://public-datasets-idc/2272a95a-b436-4f50-9165-c02267cb8fce.dcm...
# Copying gs://public-datasets-idc/f46d21ae-3582-4a28-9bd5-7788d9e7bcc3.dcm...
# Copying gs://public-datasets-idc/4359b72b-a0bb-4316-ae9c-4526d79d43a5.dcm...
# Copying gs://public-datasets-idc/aca9012f-f897-483f-91fa-6c7c4608dbdf.dcm...
# Copying gs://public-datasets-idc/b0f35b02-b4a8-401e-913b-1343401942b2.dcm...
# Copying gs://public-datasets-idc/039a2691-c467-422e-b6d6-3558da024a81.dcm...
# Copying gs://public-datasets-idc/ac2f3019-f75b-4a89-b001-3ca17355e59c.dcm...
# Copying gs://public-datasets-idc/837db10b-558a-4cea-b844-0d08ec23db69.dcm...
# Copying gs://public-datasets-idc/4359b72b-a0bb-4316-ae9c-4526d79d43a5.dcm...
# Copying gs://public-datasets-idc/5f9ad860-0422-48eb-ab15-c1ef09cf441d.dcm...
# Copying gs://public-datasets-idc/aca9012f-f897-483f-91fa-6c7c4608dbdf.dcm...
# Copying gs://public-datasets-idc/b0f35b02-b4a8-401e-913b-1343401942b2.dcm...
# Copying gs://public-datasets-idc/56866f5f-1d17-48ed-8ed3-5218adc662b5.dcm...
# Copying gs://public-datasets-idc/4123fde7-96e7-4d92-a44a-76185c41bb58.dcm...
# Copying gs://public-datasets-idc/f46d21ae-3582-4a28-9bd5-7788d9e7bcc3.dcm...
# Copying gs://public-datasets-idc/837db10b-558a-4cea-b844-0d08ec23db69.dcm...
# Copying gs://public-datasets-idc/ac2f3019-f75b-4a89-b001-3ca17355e59c.dcm...
# Copying gs://public-datasets-idc/2272a95a-b436-4f50-9165-c02267cb8fce.dcm...
# Copying gs://public-datasets-idc/c0b15cd2-fd0c-4195-88eb-88dc5c0e8306.dcm...
# Copying gs://public-datasets-idc/5f9ad860-0422-48eb-ab15-c1ef09cf441d.dcm...
# Copying gs://public-datasets-idc/4359b72b-a0bb-4316-ae9c-4526d79d43a5.dcm...
# Copying gs://public-datasets-idc/4e12e7cf-8deb-4b4b-ba76-4e25e62f55bf.dcm...
# Copying gs://public-datasets-idc/9df53637-f8a7-4966-bc72-16d26a749ce5.dcm...
# Copying gs://public-datasets-idc/837db10b-558a-4cea-b844-0d08ec23db69.dcm...
# Copying gs://public-datasets-idc/5f9ad860-0422-48eb-ab15-c1ef09cf441d.dcm...
# Copying gs://public-datasets-idc/c0b15cd2-fd0c-4195-88eb-88dc5c0e8306.dcm...
# Copying gs://public-datasets-idc/b5739c17-47fd-47cc-8546-d335ebb36c9f.dcm...
# Copying gs://public-datasets-idc/f46d21ae-3582-4a28-9bd5-7788d9e7bcc3.dcm...
# Copying gs://public-datasets-idc/4123fde7-96e7-4d92-a44a-76185c41bb58.dcm...
# Copying gs://public-datasets-idc/4e12e7cf-8deb-4b4b-ba76-4e25e62f55bf.dcm...
# Copying gs://public-datasets-idc/56866f5f-1d17-48ed-8ed3-5218adc662b5.dcm...
# Copying gs://public-datasets-idc/2272a95a-b436-4f50-9165-c02267cb8fce.dcm...
# Copying gs://public-datasets-idc/c591abfc-85c5-41d4-aa78-233da184d236.dcm...
# Copying gs://public-datasets-idc/c0b15cd2-fd0c-4195-88eb-88dc5c0e8306.dcm...
# Copying gs://public-datasets-idc/f8369548-e365-4994-a2c2-72d87db2a3b0.dcm...
# Copying gs://public-datasets-idc/9df53637-f8a7-4966-bc72-16d26a749ce5.dcm...
# Copying gs://public-datasets-idc/b5739c17-47fd-47cc-8546-d335ebb36c9f.dcm...
# Copying gs://public-datasets-idc/4e12e7cf-8deb-4b4b-ba76-4e25e62f55bf.dcm...
# Copying gs://public-datasets-idc/c591abfc-85c5-41d4-aa78-233da184d236.dcm...
# Copying gs://public-datasets-idc/2d234edb-1fd8-4204-b36e-f759fb1b7c82.dcm...
# Copying gs://public-datasets-idc/829820c7-05dd-4dfa-bf97-96d6b4296c49.dcm...
# Copying gs://public-datasets-idc/f8369548-e365-4994-a2c2-72d87db2a3b0.dcm...
# Copying gs://public-datasets-idc/49a08697-08c4-42b5-acd6-1d866fbe5b8a.dcm...
# Copying gs://public-datasets-idc/ef28d424-a16b-47b6-8624-40bd25964b36.dcm...
# Copying gs://public-datasets-idc/b5739c17-47fd-47cc-8546-d335ebb36c9f.dcm...
# Copying gs://public-datasets-idc/1f9e18c0-4e95-4138-8bdd-4fa54e70c28c.dcm...
# Copying gs://public-datasets-idc/4123fde7-96e7-4d92-a44a-76185c41bb58.dcm...
# Copying gs://public-datasets-idc/9df53637-f8a7-4966-bc72-16d26a749ce5.dcm...
# Copying gs://public-datasets-idc/c591abfc-85c5-41d4-aa78-233da184d236.dcm...
# Copying gs://public-datasets-idc/2d234edb-1fd8-4204-b36e-f759fb1b7c82.dcm...
# Copying gs://public-datasets-idc/f8369548-e365-4994-a2c2-72d87db2a3b0.dcm...
# Copying gs://public-datasets-idc/49a08697-08c4-42b5-acd6-1d866fbe5b8a.dcm...
# Copying gs://public-datasets-idc/1f9e18c0-4e95-4138-8bdd-4fa54e70c28c.dcm...
# Copying gs://public-datasets-idc/b53d1224-00c6-46d6-80d1-afc1894c300a.dcm...
# Copying gs://public-datasets-idc/47a82b42-436d-493f-94b9-e6b0b78d8d39.dcm...
# Copying gs://public-datasets-idc/799cd64c-bb5e-47e5-b59b-421aebc264c5.dcm...
# Copying gs://public-datasets-idc/ef28d424-a16b-47b6-8624-40bd25964b36.dcm...
# Copying gs://public-datasets-idc/829820c7-05dd-4dfa-bf97-96d6b4296c49.dcm...
# Copying gs://public-datasets-idc/5c3ce1af-3d3d-4e26-a5f7-f879b36d1017.dcm...
# Copying gs://public-datasets-idc/2d234edb-1fd8-4204-b36e-f759fb1b7c82.dcm...
# Copying gs://public-datasets-idc/8ae1177f-8173-47d8-a25f-0a182cdd4162.dcm...
# Copying gs://public-datasets-idc/1f9e18c0-4e95-4138-8bdd-4fa54e70c28c.dcm...
# Copying gs://public-datasets-idc/49a08697-08c4-42b5-acd6-1d866fbe5b8a.dcm...
# Copying gs://public-datasets-idc/47a82b42-436d-493f-94b9-e6b0b78d8d39.dcm...
# Copying gs://public-datasets-idc/b53d1224-00c6-46d6-80d1-afc1894c300a.dcm...
# Copying gs://public-datasets-idc/799cd64c-bb5e-47e5-b59b-421aebc264c5.dcm...
# Copying gs://public-datasets-idc/5c3ce1af-3d3d-4e26-a5f7-f879b36d1017.dcm...
# Copying gs://public-datasets-idc/28561229-a35b-4b26-80f1-105377220adf.dcm...
# Copying gs://public-datasets-idc/051007dc-0fe3-41bc-853e-bac792c90f52.dcm...
# Copying gs://public-datasets-idc/ef28d424-a16b-47b6-8624-40bd25964b36.dcm...
# \ [25 files][ 42.5 MiB/ 42.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/42.5 MiB.
# Copying gs://public-datasets-idc/829820c7-05dd-4dfa-bf97-96d6b4296c49.dcm...
# Copying gs://public-datasets-idc/799cd64c-bb5e-47e5-b59b-421aebc264c5.dcm...
# Copying gs://public-datasets-idc/b53d1224-00c6-46d6-80d1-afc1894c300a.dcm...
# Copying gs://public-datasets-idc/8ae1177f-8173-47d8-a25f-0a182cdd4162.dcm...
# Copying gs://public-datasets-idc/47a82b42-436d-493f-94b9-e6b0b78d8d39.dcm...
# Copying gs://public-datasets-idc/5c3ce1af-3d3d-4e26-a5f7-f879b36d1017.dcm...
# Copying gs://public-datasets-idc/051007dc-0fe3-41bc-853e-bac792c90f52.dcm...
# Copying gs://public-datasets-idc/07ceb61a-a73d-44ce-8317-0e439733bb85.dcm...
# Copying gs://public-datasets-idc/1ec83db4-e4f9-4daf-a18d-31121f468a57.dcm...
# Copying gs://public-datasets-idc/4e09f015-4cd2-40cb-ad8e-b44d89a2574a.dcm...
# Copying gs://public-datasets-idc/e1ceba2a-3539-495f-8b49-5bb0530fdfa7.dcm...
# Copying gs://public-datasets-idc/051007dc-0fe3-41bc-853e-bac792c90f52.dcm...
# Copying gs://public-datasets-idc/77e72f10-b3e6-4a1f-b63f-86d38d907ca0.dcm...
# Copying gs://public-datasets-idc/28561229-a35b-4b26-80f1-105377220adf.dcm...
# Copying gs://public-datasets-idc/0913b2a4-c080-4579-821d-ff5ed57623c1.dcm...
# Copying gs://public-datasets-idc/8ae1177f-8173-47d8-a25f-0a182cdd4162.dcm...
# Copying gs://public-datasets-idc/07ceb61a-a73d-44ce-8317-0e439733bb85.dcm...
# Copying gs://public-datasets-idc/4e09f015-4cd2-40cb-ad8e-b44d89a2574a.dcm...
# Copying gs://public-datasets-idc/7f37ece7-e66b-4254-b252-6f158a9e1098.dcm...
# Copying gs://public-datasets-idc/1ec83db4-e4f9-4daf-a18d-31121f468a57.dcm...
# Copying gs://public-datasets-idc/0913b2a4-c080-4579-821d-ff5ed57623c1.dcm...
# Copying gs://public-datasets-idc/77e72f10-b3e6-4a1f-b63f-86d38d907ca0.dcm...
# Copying gs://public-datasets-idc/e1ceba2a-3539-495f-8b49-5bb0530fdfa7.dcm...
# Copying gs://public-datasets-idc/07ceb61a-a73d-44ce-8317-0e439733bb85.dcm...
# Copying gs://public-datasets-idc/7f37ece7-e66b-4254-b252-6f158a9e1098.dcm...
# Copying gs://public-datasets-idc/b3469be1-c3fa-4b04-af28-355bde0f9d5e.dcm...
# Copying gs://public-datasets-idc/28561229-a35b-4b26-80f1-105377220adf.dcm...
# Copying gs://public-datasets-idc/0913b2a4-c080-4579-821d-ff5ed57623c1.dcm...
# Copying gs://public-datasets-idc/6689344c-8b81-4282-aa49-af3a29cc9527.dcm...
# Copying gs://public-datasets-idc/77e72f10-b3e6-4a1f-b63f-86d38d907ca0.dcm...
# Copying gs://public-datasets-idc/4e09f015-4cd2-40cb-ad8e-b44d89a2574a.dcm...
# Copying gs://public-datasets-idc/1ec83db4-e4f9-4daf-a18d-31121f468a57.dcm...
# | [25 files][ 29.5 MiB/ 29.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/29.5 MiB.
# Copying gs://public-datasets-idc/9edd1f09-347a-48a5-b55a-3e6aef190f61.dcm...
# Copying gs://public-datasets-idc/b3469be1-c3fa-4b04-af28-355bde0f9d5e.dcm...
# Copying gs://public-datasets-idc/e1ceba2a-3539-495f-8b49-5bb0530fdfa7.dcm...
# Copying gs://public-datasets-idc/ee210ef5-044a-4c23-944e-166bb3302b0f.dcm...
# Copying gs://public-datasets-idc/9edd1f09-347a-48a5-b55a-3e6aef190f61.dcm...
# Copying gs://public-datasets-idc/66bbd119-a2de-4c39-9b1c-f52589d5be5d.dcm...
# Copying gs://public-datasets-idc/e647adca-f68a-497a-85c7-c9539d10a810.dcm...
# Copying gs://public-datasets-idc/b3469be1-c3fa-4b04-af28-355bde0f9d5e.dcm...
# Copying gs://public-datasets-idc/aa58ed49-3a79-4602-983f-2f2d10584261.dcm...
# Copying gs://public-datasets-idc/6689344c-8b81-4282-aa49-af3a29cc9527.dcm...
# / [25 files][ 50.1 MiB/ 50.1 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# -
# Operation completed over 25 objects/50.1 MiB.
# Copying gs://public-datasets-idc/e647adca-f68a-497a-85c7-c9539d10a810.dcm...
# Copying gs://public-datasets-idc/aa58ed49-3a79-4602-983f-2f2d10584261.dcm...
# Copying gs://public-datasets-idc/ecc320fa-f410-4219-a673-02444d1c328a.dcm...
# Copying gs://public-datasets-idc/ee210ef5-044a-4c23-944e-166bb3302b0f.dcm...
# Copying gs://public-datasets-idc/bd6da63a-d2f9-4f94-8cc4-defbad89186a.dcm...
# Copying gs://public-datasets-idc/faeb20ca-2d77-49ac-aec7-732348033a09.dcm...
# Copying gs://public-datasets-idc/aa58ed49-3a79-4602-983f-2f2d10584261.dcm...
# Copying gs://public-datasets-idc/e67aeab7-5b94-4ff0-810f-f5773b23b68d.dcm...
# Copying gs://public-datasets-idc/ecc320fa-f410-4219-a673-02444d1c328a.dcm...
# Copying gs://public-datasets-idc/5ef39fd1-4561-4b1d-b156-df8009a1ebd6.dcm...
# Copying gs://public-datasets-idc/ee210ef5-044a-4c23-944e-166bb3302b0f.dcm...
# Copying gs://public-datasets-idc/bd6da63a-d2f9-4f94-8cc4-defbad89186a.dcm...
# Copying gs://public-datasets-idc/459e0f82-8d42-4202-8b7c-e1720b5ff30a.dcm...
# Copying gs://public-datasets-idc/ecc320fa-f410-4219-a673-02444d1c328a.dcm...
# Copying gs://public-datasets-idc/e67aeab7-5b94-4ff0-810f-f5773b23b68d.dcm...
# Copying gs://public-datasets-idc/5ef39fd1-4561-4b1d-b156-df8009a1ebd6.dcm...
# Copying gs://public-datasets-idc/2688dccd-cc69-4f4a-aef5-31f8442af68f.dcm...
# Copying gs://public-datasets-idc/459e0f82-8d42-4202-8b7c-e1720b5ff30a.dcm...
# Copying gs://public-datasets-idc/faeb20ca-2d77-49ac-aec7-732348033a09.dcm...
# Copying gs://public-datasets-idc/ded4f3ea-d538-4368-9761-6a7e3efba6d3.dcm...
# Copying gs://public-datasets-idc/bd6da63a-d2f9-4f94-8cc4-defbad89186a.dcm...
# Copying gs://public-datasets-idc/e67aeab7-5b94-4ff0-810f-f5773b23b68d.dcm...
# |
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/41.4 MiB.
# Copying gs://public-datasets-idc/5ef39fd1-4561-4b1d-b156-df8009a1ebd6.dcm...
# Copying gs://public-datasets-idc/2688dccd-cc69-4f4a-aef5-31f8442af68f.dcm...
# Copying gs://public-datasets-idc/ded4f3ea-d538-4368-9761-6a7e3efba6d3.dcm...
# | [17 files][ 44.3 MiB/ 44.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/28.6 MiB.
# Copying gs://public-datasets-idc/faeb20ca-2d77-49ac-aec7-732348033a09.dcm...
# Copying gs://public-datasets-idc/de073220-5463-4e7a-b83f-ec61db74645c.dcm...
# Copying gs://public-datasets-idc/e36e0862-575e-48f8-8fc1-104fbbf44d01.dcm...
# Copying gs://public-datasets-idc/2688dccd-cc69-4f4a-aef5-31f8442af68f.dcm...
# Copying gs://public-datasets-idc/ded4f3ea-d538-4368-9761-6a7e3efba6d3.dcm...
# Copying gs://public-datasets-idc/de073220-5463-4e7a-b83f-ec61db74645c.dcm...
# Copying gs://public-datasets-idc/9e6d816f-73bb-4e46-8c07-00dec8c831c1.dcm...
# Copying gs://public-datasets-idc/5f5f0840-3dee-4fb4-bab7-419cb2ecb8ad.dcm...
# Copying gs://public-datasets-idc/e36e0862-575e-48f8-8fc1-104fbbf44d01.dcm...
# Copying gs://public-datasets-idc/39a66342-0ab5-47f4-ab8a-c20da2102d02.dcm...
# Copying gs://public-datasets-idc/9e6d816f-73bb-4e46-8c07-00dec8c831c1.dcm...
# Copying gs://public-datasets-idc/de073220-5463-4e7a-b83f-ec61db74645c.dcm...
# / [25 files][ 35.8 MiB/ 35.8 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/35.8 MiB.
# - [25 files][ 52.3 MiB/ 52.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/52.3 MiB.
# Copying gs://public-datasets-idc/e36e0862-575e-48f8-8fc1-104fbbf44d01.dcm...
# Copying gs://public-datasets-idc/5f5f0840-3dee-4fb4-bab7-419cb2ecb8ad.dcm...
# Copying gs://public-datasets-idc/32c15ca0-d5a1-40c6-b680-e27b469a6a99.dcm...
# - [25 files][ 48.5 MiB/ 48.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/48.5 MiB.
# / [25 files][ 43.7 MiB/ 43.7 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/43.7 MiB.
# Copying gs://public-datasets-idc/b3804f90-1120-4f8c-b03a-31691082f426.dcm...
# Copying gs://public-datasets-idc/b3804f90-1120-4f8c-b03a-31691082f426.dcm...
# Copying gs://public-datasets-idc/a48d3187-9815-4f13-b92f-27187d4d63b7.dcm...
# Copying gs://public-datasets-idc/a48d3187-9815-4f13-b92f-27187d4d63b7.dcm...
# Copying gs://public-datasets-idc/a48d3187-9815-4f13-b92f-27187d4d63b7.dcm...
# | [25 files][ 56.8 MiB/ 56.8 MiB]    6.6 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/56.8 MiB.
# Copying gs://public-datasets-idc/80eeac52-b1a7-4032-ad4a-322d67836789.dcm...
# Copying gs://public-datasets-idc/80eeac52-b1a7-4032-ad4a-322d67836789.dcm...
# Copying gs://public-datasets-idc/80eeac52-b1a7-4032-ad4a-322d67836789.dcm...
# Copying gs://public-datasets-idc/38636f83-f883-40be-8036-19b9bdb94911.dcm...
# Copying gs://public-datasets-idc/402aed22-dc43-47cf-83ff-c8adccf38e75.dcm...
# - [4 files][  8.1 MiB/  8.1 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/38636f83-f883-40be-8036-19b9bdb94911.dcm...
# Copying gs://public-datasets-idc/402aed22-dc43-47cf-83ff-c8adccf38e75.dcm...
# Copying gs://public-datasets-idc/50a86256-64e9-42e3-b6c1-a679ffd53604.dcm...
# Copying gs://public-datasets-idc/1c21ee57-a602-4da7-827f-cab47481b3eb.dcm...
# Copying gs://public-datasets-idc/402aed22-dc43-47cf-83ff-c8adccf38e75.dcm...
# Copying gs://public-datasets-idc/50a86256-64e9-42e3-b6c1-a679ffd53604.dcm...
# Copying gs://public-datasets-idc/3bdbcbd4-ff86-4c0e-aa4e-dc1dff77d4a6.dcm...
# Copying gs://public-datasets-idc/1c21ee57-a602-4da7-827f-cab47481b3eb.dcm...
# Copying gs://public-datasets-idc/50a86256-64e9-42e3-b6c1-a679ffd53604.dcm...
# / [2 files][  1.5 MiB/  1.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/3bdbcbd4-ff86-4c0e-aa4e-dc1dff77d4a6.dcm...
# Copying gs://public-datasets-idc/c5c9ca6c-c0bb-4426-b22a-96394be3259b.dcm...
# Copying gs://public-datasets-idc/8b838447-5762-4fc9-85cf-2faacbf06a27.dcm...
# Copying gs://public-datasets-idc/3bdbcbd4-ff86-4c0e-aa4e-dc1dff77d4a6.dcm...
# Copying gs://public-datasets-idc/c5c9ca6c-c0bb-4426-b22a-96394be3259b.dcm...
# Copying gs://public-datasets-idc/021299b6-536c-4ad0-9357-45e84634592c.dcm...
# Copying gs://public-datasets-idc/8b838447-5762-4fc9-85cf-2faacbf06a27.dcm...
# Copying gs://public-datasets-idc/8bd15ce1-2198-4492-afcc-18fcd5d38a8b.dcm...
# / [0 files][    0.0 B/  3.8 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/c5c9ca6c-c0bb-4426-b22a-96394be3259b.dcm...
# Copying gs://public-datasets-idc/3b68e76c-dd24-4f1b-b3d4-c14c3a0271a2.dcm...
# Copying gs://public-datasets-idc/021299b6-536c-4ad0-9357-45e84634592c.dcm...
# Copying gs://public-datasets-idc/8b838447-5762-4fc9-85cf-2faacbf06a27.dcm...
# Copying gs://public-datasets-idc/0ce687c8-6cf0-44c3-bdd3-8791c975cf0e.dcm...
# Copying gs://public-datasets-idc/6ed2a3fd-1600-4175-8bf2-ad4e4357b3d8.dcm...
# Copying gs://public-datasets-idc/021299b6-536c-4ad0-9357-45e84634592c.dcm...
# Copying gs://public-datasets-idc/57768b62-3b9f-4bdb-be51-3cc3c2c6c145.dcm...
# Copying gs://public-datasets-idc/a4abc468-edec-430b-862f-b46ab020df03.dcm...
# Copying gs://public-datasets-idc/6ed2a3fd-1600-4175-8bf2-ad4e4357b3d8.dcm...
# Copying gs://public-datasets-idc/0ce687c8-6cf0-44c3-bdd3-8791c975cf0e.dcm...
# Copying gs://public-datasets-idc/fd1e7b6e-15a2-4612-b955-26d7155da969.dcm...
# Copying gs://public-datasets-idc/ac9c7f8a-5453-43f3-9b72-c05742966c19.dcm...
# Copying gs://public-datasets-idc/a4abc468-edec-430b-862f-b46ab020df03.dcm...
# Copying gs://public-datasets-idc/57768b62-3b9f-4bdb-be51-3cc3c2c6c145.dcm...
# Copying gs://public-datasets-idc/83c6915d-2767-4b21-bce0-56c1eb076e70.dcm...
# Copying gs://public-datasets-idc/b591ca99-309d-4c84-ab1f-2cd714051a0e.dcm...
# Copying gs://public-datasets-idc/0ce687c8-6cf0-44c3-bdd3-8791c975cf0e.dcm...
# Copying gs://public-datasets-idc/55668215-3cea-4cd6-b3c9-34c21d63e9a7.dcm...
# Copying gs://public-datasets-idc/fd1e7b6e-15a2-4612-b955-26d7155da969.dcm...
# Copying gs://public-datasets-idc/ac9c7f8a-5453-43f3-9b72-c05742966c19.dcm...
# Copying gs://public-datasets-idc/57768b62-3b9f-4bdb-be51-3cc3c2c6c145.dcm...
# Copying gs://public-datasets-idc/b591ca99-309d-4c84-ab1f-2cd714051a0e.dcm...
# Copying gs://public-datasets-idc/83c6915d-2767-4b21-bce0-56c1eb076e70.dcm...
# Copying gs://public-datasets-idc/ac9c7f8a-5453-43f3-9b72-c05742966c19.dcm...
# | [11 files][ 13.4 MiB/ 14.9 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/55668215-3cea-4cd6-b3c9-34c21d63e9a7.dcm...
# \ [14 files][ 21.3 MiB/ 21.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/4b44318a-7889-4855-8caa-bc7884de2cdd.dcm...
# Copying gs://public-datasets-idc/fa1a59e5-b1b2-4b36-b6f9-5c5e26a53d37.dcm...
# Copying gs://public-datasets-idc/fac119ba-16e4-4dcc-b354-d13b93090f60.dcm...
# Copying gs://public-datasets-idc/ada26110-bd96-4736-9c77-c7454a5a95aa.dcm...
# Copying gs://public-datasets-idc/55668215-3cea-4cd6-b3c9-34c21d63e9a7.dcm...
# Copying gs://public-datasets-idc/f8a48d4a-8b90-4af0-b16a-2a9069180695.dcm...
# Copying gs://public-datasets-idc/32d47d5e-e6f3-4738-aeac-a12ccb5019e0.dcm...
# Copying gs://public-datasets-idc/44a45b7c-655c-4aae-8764-533509f2ee4e.dcm...
# Copying gs://public-datasets-idc/fac119ba-16e4-4dcc-b354-d13b93090f60.dcm...
# Copying gs://public-datasets-idc/8b830a69-c824-4e90-bdc3-ba848f9680ae.dcm...
# Copying gs://public-datasets-idc/fa1a59e5-b1b2-4b36-b6f9-5c5e26a53d37.dcm...
# Copying gs://public-datasets-idc/32d47d5e-e6f3-4738-aeac-a12ccb5019e0.dcm...
# Copying gs://public-datasets-idc/44a45b7c-655c-4aae-8764-533509f2ee4e.dcm...
# Copying gs://public-datasets-idc/f8a48d4a-8b90-4af0-b16a-2a9069180695.dcm...
# Copying gs://public-datasets-idc/01615bc3-57c3-434e-ae6a-207d3bc611a6.dcm...
# Copying gs://public-datasets-idc/4b44318a-7889-4855-8caa-bc7884de2cdd.dcm...
# Copying gs://public-datasets-idc/ada26110-bd96-4736-9c77-c7454a5a95aa.dcm...
# \
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/fac119ba-16e4-4dcc-b354-d13b93090f60.dcm...
# Copying gs://public-datasets-idc/8b830a69-c824-4e90-bdc3-ba848f9680ae.dcm...
# Copying gs://public-datasets-idc/bf1e495e-5b73-4efa-8a63-d80b8426034a.dcm...
# -
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/32d47d5e-e6f3-4738-aeac-a12ccb5019e0.dcm...
# Copying gs://public-datasets-idc/01615bc3-57c3-434e-ae6a-207d3bc611a6.dcm...
# Copying gs://public-datasets-idc/f8a48d4a-8b90-4af0-b16a-2a9069180695.dcm...
# Copying gs://public-datasets-idc/e83ae298-ad39-4ec1-94c0-a68e712c631f.dcm...
# Copying gs://public-datasets-idc/1b6ce62a-4849-4943-b73a-f55e508073c1.dcm...
# Copying gs://public-datasets-idc/8b830a69-c824-4e90-bdc3-ba848f9680ae.dcm...
# Copying gs://public-datasets-idc/65c5a348-a86c-49fb-9b46-c07071e7f388.dcm...
# Copying gs://public-datasets-idc/1cb9c65a-1082-4641-a591-6c781f12b167.dcm...
# Copying gs://public-datasets-idc/9b57dbc7-2aaf-43c7-bacc-402c635914bb.dcm...
# Copying gs://public-datasets-idc/ada26110-bd96-4736-9c77-c7454a5a95aa.dcm...
# Copying gs://public-datasets-idc/4b44318a-7889-4855-8caa-bc7884de2cdd.dcm...
# Copying gs://public-datasets-idc/bea6c4a2-b382-4117-80a0-5a078464acb4.dcm...
# Copying gs://public-datasets-idc/bf1e495e-5b73-4efa-8a63-d80b8426034a.dcm...
# Copying gs://public-datasets-idc/e83ae298-ad39-4ec1-94c0-a68e712c631f.dcm...
# Copying gs://public-datasets-idc/24cc6ae4-187b-4259-9368-9a86bf5abd90.dcm...
# Copying gs://public-datasets-idc/c0b4db09-e41d-475e-919b-57ed41997f19.dcm...
# Copying gs://public-datasets-idc/bea6c4a2-b382-4117-80a0-5a078464acb4.dcm...
# Copying gs://public-datasets-idc/9b57dbc7-2aaf-43c7-bacc-402c635914bb.dcm...
# Copying gs://public-datasets-idc/65c5a348-a86c-49fb-9b46-c07071e7f388.dcm...
# Copying gs://public-datasets-idc/e83ae298-ad39-4ec1-94c0-a68e712c631f.dcm...
# Copying gs://public-datasets-idc/2de72a55-26d8-4d08-9bcc-38f4ebbde413.dcm...
# Copying gs://public-datasets-idc/bea6c4a2-b382-4117-80a0-5a078464acb4.dcm...
# Copying gs://public-datasets-idc/24cc6ae4-187b-4259-9368-9a86bf5abd90.dcm...
# Copying gs://public-datasets-idc/c0b4db09-e41d-475e-919b-57ed41997f19.dcm...
# Copying gs://public-datasets-idc/1cb9c65a-1082-4641-a591-6c781f12b167.dcm...
# Copying gs://public-datasets-idc/bf1e495e-5b73-4efa-8a63-d80b8426034a.dcm...
# Copying gs://public-datasets-idc/8357ed27-faab-456a-9236-f88396189358.dcm...
# Copying gs://public-datasets-idc/9b57dbc7-2aaf-43c7-bacc-402c635914bb.dcm...
# Copying gs://public-datasets-idc/24cc6ae4-187b-4259-9368-9a86bf5abd90.dcm...
# Copying gs://public-datasets-idc/1eb1c831-0b67-4060-ac8c-8d526384e06e.dcm...
# Copying gs://public-datasets-idc/c0b4db09-e41d-475e-919b-57ed41997f19.dcm...
# Copying gs://public-datasets-idc/b3d8cfd0-376f-4f7a-b440-62091684b37b.dcm...
# Copying gs://public-datasets-idc/07db1d98-22f3-424d-a063-2f4faf5ad632.dcm...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/8357ed27-faab-456a-9236-f88396189358.dcm...
# Copying gs://public-datasets-idc/2de72a55-26d8-4d08-9bcc-38f4ebbde413.dcm...
# Copying gs://public-datasets-idc/f8dbf5f6-3c1c-4dd0-a4a4-4e4ca271b583.dcm...
# Copying gs://public-datasets-idc/48d8b383-3c83-4728-9292-1c7155f7581c.dcm...
# Copying gs://public-datasets-idc/59a0d450-f21a-433d-8aec-ff9858a6c1ee.dcm...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/1cb9c65a-1082-4641-a591-6c781f12b167.dcm...
# / [8 files][ 11.9 MiB/ 13.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/fc9496e0-2068-473e-8371-06d7a1ed41ee.dcm...
# Copying gs://public-datasets-idc/8357ed27-faab-456a-9236-f88396189358.dcm...
# Copying gs://public-datasets-idc/b3d8cfd0-376f-4f7a-b440-62091684b37b.dcm...
# Copying gs://public-datasets-idc/1eb1c831-0b67-4060-ac8c-8d526384e06e.dcm...
# Copying gs://public-datasets-idc/07db1d98-22f3-424d-a063-2f4faf5ad632.dcm...
# Copying gs://public-datasets-idc/48d8b383-3c83-4728-9292-1c7155f7581c.dcm...
# Copying gs://public-datasets-idc/254be741-1aa6-4271-90c3-1da73fb399d9.dcm...
# Copying gs://public-datasets-idc/59a0d450-f21a-433d-8aec-ff9858a6c1ee.dcm...
# Copying gs://public-datasets-idc/fc9496e0-2068-473e-8371-06d7a1ed41ee.dcm...
# Copying gs://public-datasets-idc/07db1d98-22f3-424d-a063-2f4faf5ad632.dcm...
# Copying gs://public-datasets-idc/1eb1c831-0b67-4060-ac8c-8d526384e06e.dcm...
# Copying gs://public-datasets-idc/b3d8cfd0-376f-4f7a-b440-62091684b37b.dcm...
# Copying gs://public-datasets-idc/e2cc50aa-96a9-4fcd-8bc4-af5e95b65483.dcm...
# Copying gs://public-datasets-idc/48d8b383-3c83-4728-9292-1c7155f7581c.dcm...
# Copying gs://public-datasets-idc/f8dbf5f6-3c1c-4dd0-a4a4-4e4ca271b583.dcm...
# Copying gs://public-datasets-idc/1095d9e9-0b2d-4126-84ff-acbc9ddc8d65.dcm...
# Copying gs://public-datasets-idc/59a0d450-f21a-433d-8aec-ff9858a6c1ee.dcm...
# Copying gs://public-datasets-idc/fc9496e0-2068-473e-8371-06d7a1ed41ee.dcm...
# Copying gs://public-datasets-idc/33da74b9-c0dd-4745-8222-20e0bb49689a.dcm...
# Copying gs://public-datasets-idc/254be741-1aa6-4271-90c3-1da73fb399d9.dcm...
# Copying gs://public-datasets-idc/3fa71302-051c-4900-9744-63917ab55ea0.dcm...
# Copying gs://public-datasets-idc/1095d9e9-0b2d-4126-84ff-acbc9ddc8d65.dcm...
# Copying gs://public-datasets-idc/d2552be5-5750-4166-8b0f-a28c7a1db873.dcm...
# Copying gs://public-datasets-idc/e2cc50aa-96a9-4fcd-8bc4-af5e95b65483.dcm...
# Copying gs://public-datasets-idc/d4de239d-de37-4907-a281-28957dcde494.dcm...
# Copying gs://public-datasets-idc/52a01ec1-b75e-444d-b503-8b47d337cce8.dcm...
# Copying gs://public-datasets-idc/ef3266d3-6bec-4a8c-85fb-e0a031c5e51c.dcm...
# Copying gs://public-datasets-idc/33da74b9-c0dd-4745-8222-20e0bb49689a.dcm...
# Copying gs://public-datasets-idc/f8dbf5f6-3c1c-4dd0-a4a4-4e4ca271b583.dcm...
# Copying gs://public-datasets-idc/3fa71302-051c-4900-9744-63917ab55ea0.dcm...
# Copying gs://public-datasets-idc/e2cc50aa-96a9-4fcd-8bc4-af5e95b65483.dcm...
# Copying gs://public-datasets-idc/c8e96ece-8d2c-45e0-ab59-c8c027c4b4f3.dcm...
# Copying gs://public-datasets-idc/33da74b9-c0dd-4745-8222-20e0bb49689a.dcm...
# Copying gs://public-datasets-idc/ef3266d3-6bec-4a8c-85fb-e0a031c5e51c.dcm...
# Copying gs://public-datasets-idc/52a01ec1-b75e-444d-b503-8b47d337cce8.dcm...
# Copying gs://public-datasets-idc/d2552be5-5750-4166-8b0f-a28c7a1db873.dcm...
# Copying gs://public-datasets-idc/3fa71302-051c-4900-9744-63917ab55ea0.dcm...
# Copying gs://public-datasets-idc/02d60b41-cdae-43bb-a863-b91a64c156d0.dcm...
# Copying gs://public-datasets-idc/d4de239d-de37-4907-a281-28957dcde494.dcm...
# Copying gs://public-datasets-idc/c8e96ece-8d2c-45e0-ab59-c8c027c4b4f3.dcm...
# Copying gs://public-datasets-idc/0d4fae73-ab48-4340-abd0-f0b162e75304.dcm...
# Copying gs://public-datasets-idc/02d60b41-cdae-43bb-a863-b91a64c156d0.dcm...
# | [16 files][ 27.4 MiB/ 28.9 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/40.3 MiB.
# Copying gs://public-datasets-idc/ef3266d3-6bec-4a8c-85fb-e0a031c5e51c.dcm...
# Copying gs://public-datasets-idc/c8e96ece-8d2c-45e0-ab59-c8c027c4b4f3.dcm...
# Copying gs://public-datasets-idc/bfd69450-0961-4f2b-b258-90e608607810.dcm...
# Copying gs://public-datasets-idc/1c21ee57-a602-4da7-827f-cab47481b3eb.dcm...
# Copying gs://public-datasets-idc/a2ba6d65-e701-44f5-a194-9edfc7df8bc5.dcm...
# Copying gs://public-datasets-idc/02d60b41-cdae-43bb-a863-b91a64c156d0.dcm...
# Copying gs://public-datasets-idc/52a01ec1-b75e-444d-b503-8b47d337cce8.dcm...
# Copying gs://public-datasets-idc/d2552be5-5750-4166-8b0f-a28c7a1db873.dcm...
# Copying gs://public-datasets-idc/1095d9e9-0b2d-4126-84ff-acbc9ddc8d65.dcm...
# Copying gs://public-datasets-idc/0d4fae73-ab48-4340-abd0-f0b162e75304.dcm...
# - [25 files][ 28.5 MiB/ 28.5 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/28.5 MiB.
# Copying gs://public-datasets-idc/20e29202-8774-415d-861e-c34f9b1d036c.dcm...
# Copying gs://public-datasets-idc/d93eecb2-e5f6-4bd0-9ca6-54319bc17e01.dcm...
# Copying gs://public-datasets-idc/a2ba6d65-e701-44f5-a194-9edfc7df8bc5.dcm...
# Copying gs://public-datasets-idc/bfd69450-0961-4f2b-b258-90e608607810.dcm...
# Copying gs://public-datasets-idc/2495cb08-e23e-422e-bee5-388aa0162fe7.dcm...
# Copying gs://public-datasets-idc/3672b107-a2ea-44db-bb6e-c5d02f693c7d.dcm...
# Copying gs://public-datasets-idc/d93eecb2-e5f6-4bd0-9ca6-54319bc17e01.dcm...
# Copying gs://public-datasets-idc/20e29202-8774-415d-861e-c34f9b1d036c.dcm...
# Copying gs://public-datasets-idc/c6750bd0-b317-4239-96b5-e94f11617e3a.dcm...
# Copying gs://public-datasets-idc/0d4fae73-ab48-4340-abd0-f0b162e75304.dcm...
# Copying gs://public-datasets-idc/a2ba6d65-e701-44f5-a194-9edfc7df8bc5.dcm...
# Copying gs://public-datasets-idc/d93eecb2-e5f6-4bd0-9ca6-54319bc17e01.dcm...
# Copying gs://public-datasets-idc/20e29202-8774-415d-861e-c34f9b1d036c.dcm...
# Copying gs://public-datasets-idc/2495cb08-e23e-422e-bee5-388aa0162fe7.dcm...
# Copying gs://public-datasets-idc/3ee3d4d9-dc89-4e32-b693-482d56c98d3f.dcm...
# Copying gs://public-datasets-idc/c6750bd0-b317-4239-96b5-e94f11617e3a.dcm...
# Copying gs://public-datasets-idc/3672b107-a2ea-44db-bb6e-c5d02f693c7d.dcm...
# Copying gs://public-datasets-idc/34ac546c-5eae-4b1c-83fc-7e39e213a5e1.dcm...
# Copying gs://public-datasets-idc/1575fe22-c8f0-4a66-83d1-a0441bae3345.dcm...
# Copying gs://public-datasets-idc/3ee3d4d9-dc89-4e32-b693-482d56c98d3f.dcm...
# Copying gs://public-datasets-idc/3edc5e86-31c2-4cf3-b901-5f8ea6fa764b.dcm...
# Copying gs://public-datasets-idc/62db2269-d09c-471f-9f39-6b1c371cefcc.dcm...
# Copying gs://public-datasets-idc/2495cb08-e23e-422e-bee5-388aa0162fe7.dcm...
# Copying gs://public-datasets-idc/c6750bd0-b317-4239-96b5-e94f11617e3a.dcm...
# Copying gs://public-datasets-idc/3672b107-a2ea-44db-bb6e-c5d02f693c7d.dcm...
# Copying gs://public-datasets-idc/34ac546c-5eae-4b1c-83fc-7e39e213a5e1.dcm...
# Copying gs://public-datasets-idc/3ee3d4d9-dc89-4e32-b693-482d56c98d3f.dcm...
# Copying gs://public-datasets-idc/61ce346d-c839-4132-addc-c8c624c470b0.dcm...
# Copying gs://public-datasets-idc/1575fe22-c8f0-4a66-83d1-a0441bae3345.dcm...
# Copying gs://public-datasets-idc/3b68e76c-dd24-4f1b-b3d4-c14c3a0271a2.dcm...
# Copying gs://public-datasets-idc/34ac546c-5eae-4b1c-83fc-7e39e213a5e1.dcm...
# Copying gs://public-datasets-idc/314b5a35-bb84-4e8c-bc94-273104556616.dcm...
# Copying gs://public-datasets-idc/3edc5e86-31c2-4cf3-b901-5f8ea6fa764b.dcm...
# Copying gs://public-datasets-idc/d148919e-2c32-4501-9315-3f55c2ba31a5.dcm...
# Copying gs://public-datasets-idc/62db2269-d09c-471f-9f39-6b1c371cefcc.dcm...
# Copying gs://public-datasets-idc/314b5a35-bb84-4e8c-bc94-273104556616.dcm...
# Copying gs://public-datasets-idc/61ce346d-c839-4132-addc-c8c624c470b0.dcm...
# Copying gs://public-datasets-idc/3b68e76c-dd24-4f1b-b3d4-c14c3a0271a2.dcm...
# Copying gs://public-datasets-idc/3d7a4e14-5a45-4bd1-9609-3a1274ccde83.dcm...
# Copying gs://public-datasets-idc/1575fe22-c8f0-4a66-83d1-a0441bae3345.dcm...
# Copying gs://public-datasets-idc/3edc5e86-31c2-4cf3-b901-5f8ea6fa764b.dcm...
# Copying gs://public-datasets-idc/d148919e-2c32-4501-9315-3f55c2ba31a5.dcm...
# Copying gs://public-datasets-idc/314b5a35-bb84-4e8c-bc94-273104556616.dcm...
# / [25 files][ 46.1 MiB/ 46.1 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/46.1 MiB.
# Copying gs://public-datasets-idc/61ce346d-c839-4132-addc-c8c624c470b0.dcm...
# Copying gs://public-datasets-idc/3d7a4e14-5a45-4bd1-9609-3a1274ccde83.dcm...
# Copying gs://public-datasets-idc/b591ca99-309d-4c84-ab1f-2cd714051a0e.dcm...
# Copying gs://public-datasets-idc/62db2269-d09c-471f-9f39-6b1c371cefcc.dcm...
# Copying gs://public-datasets-idc/3d7a4e14-5a45-4bd1-9609-3a1274ccde83.dcm...
# Copying gs://public-datasets-idc/445ed36e-2e3b-4e2a-bf28-724b9ddfd58f.dcm...
# Copying gs://public-datasets-idc/6d3d17e8-e0cc-40d5-8c9d-6fd4357599dc.dcm...
# Copying gs://public-datasets-idc/7fcbf02d-d1f6-48ef-91ef-4e21ae23b66d.dcm...
# Copying gs://public-datasets-idc/e5bc82d6-f0f2-42d3-b8a3-a7aecd5cbcc7.dcm...
# Copying gs://public-datasets-idc/dde9dc02-a3f9-4953-8a01-1ab83d842259.dcm...
# Copying gs://public-datasets-idc/445ed36e-2e3b-4e2a-bf28-724b9ddfd58f.dcm...
# |
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/38.7 MiB.
# Copying gs://public-datasets-idc/7fcbf02d-d1f6-48ef-91ef-4e21ae23b66d.dcm...
# Copying gs://public-datasets-idc/94c780c9-739e-4fe9-a8c4-85569f6b72dc.dcm...
# Copying gs://public-datasets-idc/e5bc82d6-f0f2-42d3-b8a3-a7aecd5cbcc7.dcm...
# Copying gs://public-datasets-idc/6d3d17e8-e0cc-40d5-8c9d-6fd4357599dc.dcm...
# Copying gs://public-datasets-idc/7fcbf02d-d1f6-48ef-91ef-4e21ae23b66d.dcm...
# Copying gs://public-datasets-idc/445ed36e-2e3b-4e2a-bf28-724b9ddfd58f.dcm...
# Copying gs://public-datasets-idc/94c780c9-739e-4fe9-a8c4-85569f6b72dc.dcm...
# Copying gs://public-datasets-idc/dde9dc02-a3f9-4953-8a01-1ab83d842259.dcm...
# Copying gs://public-datasets-idc/e5bc82d6-f0f2-42d3-b8a3-a7aecd5cbcc7.dcm...
# Copying gs://public-datasets-idc/59c136f7-1e65-48a3-ae57-11caa2acefc9.dcm...
# Copying gs://public-datasets-idc/d3f28dc9-7aee-40f0-a400-3f365f152986.dcm...
# Copying gs://public-datasets-idc/a430f4dc-3120-40fa-86b0-9ae0c8bb028b.dcm...
# Copying gs://public-datasets-idc/94c780c9-739e-4fe9-a8c4-85569f6b72dc.dcm...
# Copying gs://public-datasets-idc/01615bc3-57c3-434e-ae6a-207d3bc611a6.dcm...
# / [25 files][ 35.0 MiB/ 35.0 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/35.0 MiB.
# Copying gs://public-datasets-idc/59c136f7-1e65-48a3-ae57-11caa2acefc9.dcm...
# Copying gs://public-datasets-idc/a430f4dc-3120-40fa-86b0-9ae0c8bb028b.dcm...
# Copying gs://public-datasets-idc/dde9dc02-a3f9-4953-8a01-1ab83d842259.dcm...
# Copying gs://public-datasets-idc/d3f28dc9-7aee-40f0-a400-3f365f152986.dcm...
# Copying gs://public-datasets-idc/8bd15ce1-2198-4492-afcc-18fcd5d38a8b.dcm...
# Copying gs://public-datasets-idc/a430f4dc-3120-40fa-86b0-9ae0c8bb028b.dcm...
# Copying gs://public-datasets-idc/d96830ca-9a2f-4895-8b03-9f2b966cb95d.dcm...
# Copying gs://public-datasets-idc/d3f28dc9-7aee-40f0-a400-3f365f152986.dcm...
# Copying gs://public-datasets-idc/7dc5d5d6-3b18-4c26-a2e4-f05997618f66.dcm...
# Copying gs://public-datasets-idc/8bd15ce1-2198-4492-afcc-18fcd5d38a8b.dcm...
# Copying gs://public-datasets-idc/fd1e7b6e-15a2-4612-b955-26d7155da969.dcm...
# Copying gs://public-datasets-idc/d96830ca-9a2f-4895-8b03-9f2b966cb95d.dcm...
# - [25 files][ 45.9 MiB/ 45.9 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/45.9 MiB.
# Copying gs://public-datasets-idc/d40385cc-5fe3-4428-b011-3057ee7941a2.dcm...
# Copying gs://public-datasets-idc/7dc5d5d6-3b18-4c26-a2e4-f05997618f66.dcm...
# Copying gs://public-datasets-idc/d96830ca-9a2f-4895-8b03-9f2b966cb95d.dcm...
# | [25 files][ 63.7 MiB/ 63.7 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/63.7 MiB.
# Copying gs://public-datasets-idc/d40385cc-5fe3-4428-b011-3057ee7941a2.dcm...
# Copying gs://public-datasets-idc/1b6ce62a-4849-4943-b73a-f55e508073c1.dcm...
# Copying gs://public-datasets-idc/7dc5d5d6-3b18-4c26-a2e4-f05997618f66.dcm...
# Copying gs://public-datasets-idc/d40385cc-5fe3-4428-b011-3057ee7941a2.dcm...
# Copying gs://public-datasets-idc/1b6ce62a-4849-4943-b73a-f55e508073c1.dcm...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/52.1 MiB.
# Copying gs://public-datasets-idc/837d0a3b-b265-4e3f-9cda-df701c268cc8.dcm...
# Copying gs://public-datasets-idc/864543fe-9efe-4515-8579-cbdc2c9fee66.dcm...
# - [25 files][ 53.6 MiB/ 53.6 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/53.6 MiB.
# Copying gs://public-datasets-idc/837d0a3b-b265-4e3f-9cda-df701c268cc8.dcm...
# \ [25 files][ 47.2 MiB/ 47.2 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/47.2 MiB.
# Copying gs://public-datasets-idc/864543fe-9efe-4515-8579-cbdc2c9fee66.dcm...
# Copying gs://public-datasets-idc/864543fe-9efe-4515-8579-cbdc2c9fee66.dcm...
# Copying gs://public-datasets-idc/5fe61abc-2961-4baa-95a3-412a5aa1d3b5.dcm...
# Copying gs://public-datasets-idc/80f2eec5-e6b2-41b7-9ba7-9a7ed5c95737.dcm...
# Copying gs://public-datasets-idc/5fe61abc-2961-4baa-95a3-412a5aa1d3b5.dcm...
# Copying gs://public-datasets-idc/80f2eec5-e6b2-41b7-9ba7-9a7ed5c95737.dcm...
# / [4 files][  5.8 MiB/  5.8 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/5fe61abc-2961-4baa-95a3-412a5aa1d3b5.dcm...
# Copying gs://public-datasets-idc/80f2eec5-e6b2-41b7-9ba7-9a7ed5c95737.dcm...
# Copying gs://public-datasets-idc/32a4c94b-1057-4535-be91-4f4e54f4b6ad.dcm...
# Copying gs://public-datasets-idc/c2ddd0fb-caea-4bea-ba12-0e7205dcd1df.dcm...
# Copying gs://public-datasets-idc/9ea63052-3814-489f-a6f7-eb7ef62615df.dcm...
# / [4 files][  5.6 MiB/  5.6 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://public-datasets-idc/c2ddd0fb-caea-4bea-ba12-0e7205dcd1df.dcm...
# Copying gs://public-datasets-idc/9ea63052-3814-489f-a6f7-eb7ef62615df.dcm...
# / [5 files][  6.2 MiB/  6.2 MiB]
# Operation completed over 5 objects/6.2 MiB.
# Copying gs://public-datasets-idc/9ea63052-3814-489f-a6f7-eb7ef62615df.dcm...
# Copying gs://public-datasets-idc/0a4bec4a-7b83-4405-9371-beb39d3764e2.dcm...
# Copying gs://public-datasets-idc/0a4bec4a-7b83-4405-9371-beb39d3764e2.dcm...
# Copying gs://public-datasets-idc/0a4bec4a-7b83-4405-9371-beb39d3764e2.dcm...
# Copying gs://public-datasets-idc/bbd5380b-2f7c-4164-a8ae-1845df3b4fde.dcm...
# Copying gs://public-datasets-idc/bbd5380b-2f7c-4164-a8ae-1845df3b4fde.dcm...
# Copying gs://public-datasets-idc/fb8b58b3-9f00-4623-9b01-0ad489b83efb.dcm...
# Copying gs://public-datasets-idc/fb8b58b3-9f00-4623-9b01-0ad489b83efb.dcm...
# Copying gs://public-datasets-idc/fb8b58b3-9f00-4623-9b01-0ad489b83efb.dcm...
# Copying gs://public-datasets-idc/5b8fb3d6-7d74-4751-950a-b7478fd33e06.dcm...
# Copying gs://public-datasets-idc/5b8fb3d6-7d74-4751-950a-b7478fd33e06.dcm...
# Copying gs://public-datasets-idc/5b8fb3d6-7d74-4751-950a-b7478fd33e06.dcm...
# Copying gs://public-datasets-idc/893947fc-dbd8-45a9-9aeb-216819b811cf.dcm...
# Copying gs://public-datasets-idc/893947fc-dbd8-45a9-9aeb-216819b811cf.dcm...
# Copying gs://public-datasets-idc/893947fc-dbd8-45a9-9aeb-216819b811cf.dcm...
# Copying gs://public-datasets-idc/7540b951-70e5-449b-8747-79397bfede9a.dcm...
# Copying gs://public-datasets-idc/7540b951-70e5-449b-8747-79397bfede9a.dcm...
# / [25 files][ 45.3 MiB/ 45.3 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 25 objects/45.3 MiB.

# %% [markdown]
# ## `s5cmd`
#
# See details in https://learn.canceridc.dev/data/downloading-data/downloading-data-with-s5cmd.
#
# The steps below assume you created a Service Account, generated a key, and saved your credentials in Google Drive (those steps are covered in the aforementioned documentation article).

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# !mkdir -p ~/.aws
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/aws/credentials ~/.aws

# %%
# !wget https://github.com/peak/s5cmd/releases/download/v2.0.0/s5cmd_2.0.0_Linux-64bit.tar.gz
# !tar zxf s5cmd_2.0.0_Linux-64bit.tar.gz
# !mv s5cmd /usr/bin

# %% [markdown]
# The cell below is just a quick test to confirm that the setup is working. If the file is copied without issues, we are all set.

# %%
# !s5cmd --endpoint-url https://storage.googleapis.com cp s3://public-datasets-idc/eae91afc-1977-4728-9d6a-06f782c696d4.dcm .

# %% [markdown]
# Content of the manifest that can be used with `s5cmd` is a bit different. The cell below demonstrates how to create it.

# %%
# create s5cmd manifest file for the subsequent download of files
import os
try:
  os.mkdir("s5cmd_downloaded_files")
except FileExistsError:
  pass
("cp "+selection_df["gcs_url"].replace(to_replace="gs://",value="s3://", regex=True)+" s5cmd_downloaded_files").to_csv("s5cmd_manifest.txt", header=False, index=False)

# %% [markdown]
# Once manifest is ready, use the following command to download the files.

# %%
# %%capture
# !s5cmd --endpoint-url https://storage.googleapis.com run s5cmd_manifest.txt

# %% [markdown]
# # Sorting

# %%
# %%capture
# !pip install pydicom
# !git clone https://github.com/pieper/dicomsort
# !sudo apt-get install dcmtk

# %%
import os
os.environ["SORTED_DEST"] = "/content/IDC_sorted"

# !mkdir -p $SORTED_DEST
# !rm -rf $SORTED_DEST/*
# !python dicomsort/dicomsort.py -k -u $DOWNLOAD_DEST ${SORTED_DEST}/%StudyInstanceUID/%SeriesInstanceUID/%SOPInstanceUID.dcm
# Out:
# 100% 188/188 [00:40<00:00,  4.62it/s]
# Files sorted

# %% [markdown]
# # Misc
#
# ## Mount Google Drive
#
# Since everything you save in your Colab instance will disappear after restart, you may want to use some persistent location, such as Google Drive, for saving your artifacts.

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
